# %% [markdown]
# # Netflix Dataset Analysis using Pandas

# %% [markdown]
# <img src='netflix.png' border=20 width='50%' heigth='50px' >

# %% [markdown]
# ## This Netflix Dataset has information about the TV Showsee.

# %% [markdown]
# ## and Movies available on Netflix till 2021.
#
# ## This dataset is collected from Flixable which is a third-party
# ## Netflix search engine, and available on Kaggle website for free.

# %% [markdown]
# # Q1. To show top-5 records of the dataset?' & Type is 'Kids' TV' ?

# %%
import pandas as p

# %%
d=p.read_csv('dataset/Netflix.csv')

# %%
d[d['Type'].str.contains("Kids' TV")].head()
# Out:
#     Show_Id Category                           Title     Director  \
# 108    s109  TV Show        3Below: Tales of Arcadia          NaN
# 111    s112  TV Show                         44 Cats          NaN
# 225    s226  TV Show  A Series of Unfortunate Events          NaN
# 276    s277  TV Show                    Abby Hatcher  Kyran Kelly
# 364    s365  TV Show                    Akbar Birbal          NaN
#
#                                                   Cast                Country  \
# 108  Tatiana Maslany, Diego Luna, Nick Offerman, Ni...          United States
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 225  Neil Patrick Harris, Patrick Warburton, Malina...          United States
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 364          Kiku Sharda, Vishal Kotian, Delnaaz Irani                  India
#
#         Release_Date Rating   Duration  \
# 108    July 12, 2019  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ## Only Kids' TV

# %%
d[d['Type']=="Kids' TV"].head()
# Out:
#     Show_Id Category              Title             Director  \
# 111    s112  TV Show            44 Cats                  NaN
# 276    s277  TV Show       Abby Hatcher          Kyran Kelly
# 434    s435  TV Show        Alphablocks                  NaN
# 598    s599  TV Show  Ask the StoryBots                  NaN
# 706    s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 434    Teresa Gallagher, David Holt, Lizzie Waterworth         United Kingdom
# 598  Judy Greer, Erin Fitzgerald, Fred Tatasciore, ...          United States
# 706             Meghna Erande Joshi, Parminder Ghumman                    NaN
#
#         Release_Date Rating   Duration      Type  \
# 111  October 1, 2020  TV-Y7  2 Seasons  Kids' TV
# ...

# %% [markdown]
# # Q2. To show bottom-5 records of dataset?

# %%
d[d['Type']=="Kids' TV"].tail()
# Out:
#      Show_Id Category          Title        Director  \
# 7668   s7667  TV Show  World of Winx  Iginio Straffi
# 7717   s7716  TV Show           Yoko             NaN
# 7719   s7718  TV Show            YOM             NaN
# 7758   s7757  TV Show             Z4             NaN
# 7761   s7760  TV Show      Zak Storm             NaN
#
#                                                    Cast  \
# 7668  Haven Paschall, Alysha Deslorieux, Jessica Paq...
# 7717  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...
# 7719  Sairaj, Devyani Dagaonkar, Ketan Singh, Mayur ...
# 7758  Apollo Costa, Gabriel Santana, Matheus Lustosa...
# 7761  Michael Johnston, Jessica Gee-George, Christin...
#
#                                             Country        Release_Date  \
# 7668                           Italy, United States       June 16, 2017
# 7717                                            NaN       June 23, 2018
# 7719                                            NaN        June 7, 2018
# ...

# %%
d[d['Type'].str.contains("Kids' TV")].tail()
# Out:
#      Show_Id Category         Title Director  \
# 7758   s7757  TV Show            Z4      NaN
# 7761   s7760  TV Show     Zak Storm      NaN
# 7768   s7767  TV Show  Zig & Sharko      NaN
# 7777   s7776  TV Show    Zoids Wild      NaN
# 7779   s7778  TV Show   Zombie Dumb      NaN
#
#                                                    Cast  \
# 7758  Apollo Costa, Gabriel Santana, Matheus Lustosa...
# 7761  Michael Johnston, Jessica Gee-George, Christin...
# 7768                                                NaN
# 7777  Kensho Ono, Takahiro Sakurai, Mikako Komatsu, ...
# 7779                                                NaN
#
#                                             Country        Release_Date  \
# 7758                                         Brazil   February 22, 2019
# 7761  United States, France, South Korea, Indonesia  September 13, 2018
# 7768                                         France    December 1, 2017
# ...

# %% [markdown]
# # Q3. To show the No. of Rows and Columns?

# %%
print("No. of Rows :",d.shape[0])
# Out:
# No. of Rows : 7789

# %%
print('No. of Columns:',d.shape[1])
# Out:
# No. of Columns: 11

# %% [markdown]
# # Q4. To show each Column Name?

# %%
d.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # Q5. To show the data-type of each column?

# %%
d.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# # Q6. To show indexes, columns, data-types of each column, memory at once?

# %%
print(' cloumns\n',d.columns,'\ndata-types\n',d.dtypes,'\nmemory\n',d.memory_usage(deep=True))
# Out:
#  cloumns
#  Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')
# data-types
#  Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object
# memory
#  Index               132
# Show_Id          481810
# Category         487738
# Title            587966
# Director         475502
# Cast            1311385
# Country          521614
# Release_Date     559360
# Rating           478428
# Duration         498872
# Type             703732
# Description     1717998
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Q7. Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
d.duplicated().sum()
# Out:
# 2

# %%
d.shape
# Out:
# (7789, 11)

# %%
d.drop_duplicates(inplace=True)

# %%
d.shape
# Out:
# (7787, 11)

# %% [markdown]
# # Q8. Is there any Null Value present in any column ?

# %%
d.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# # Q9. For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
d[d['Title']=='House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
d[d['Title']=='House of Cards'].iloc[:,[0,3]]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# ## Isin()

# %%
d[d['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## str.contains()

# %%
d[d['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Q10.In which year highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %% [markdown]
# ###  to_datetime

# %%
d['Release_Date']=p.to_datetime(d['Release_Date'],format='mixed')

# %%
d['Year']=d.Release_Date.dt.year

# %%
d.Year.value_counts()
# Out:
# Year
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
d.Year.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# # Q11. How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
print(d.Category.value_counts())
d.Category.value_counts().plot(kind='bar')
plt.show()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
d.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# # Q12. Show all the Movies that were released in year 2000?

# %%
d.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Year'],
#       dtype='object')

# %%
m=d[d['Category']=="Movie"]
m[m['Year']==2000]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Year]
# Index: []

# %%
d['Year'].unique()
# Out:
# array([2020., 2016., 2018., 2017., 2019., 2021., 2015., 2013., 2011.,
#          nan, 2012., 2014., 2008., 2009., 2010.])

# %%
d[(d['Category']=='Movie') & (d['Year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Year]
# Index: []

# %% [markdown]
# # Q13. Show only the Titles of all TV Shows that were released in India only?

# %%
t=d[d['Country']=='India']
t[t['Category']=='TV Show'].iloc[:,[2]]
# Out:
#                                    Title
# 86          21 Sarfarosh: Saragarhi 1897
# 132                            7 (Seven)
# 340                         Agent Raghav
# 364                         Akbar Birbal
# 533                  Anjaan: Rural Myths
# ...                                  ...
# 6249                The Creative Indians
# 6400  The Golden Years with Javed Akhtar
# 6469              The House That Made Me
# 7294                          Typewriter
# 7705                     Yeh Meri Family
#
# [71 rows x 1 columns]

# %%
d[(d['Category']=='TV Show')& (d['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Q14. Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
t=d.groupby(by='Category')
t.Director.value_counts().head(10)
# Out:
# Category  Director
# Movie     Raúl Campos, Jan Suter    18
#           Marcus Raboy              15
#           Jay Karas                 14
#           Cathy Garcia-Molina       13
#           Youssef Chahine           12
#           Jay Chapman               12
#           Martin Scorsese           12
#           Steven Spielberg          10
#           David Dhawan               9
#           Hakan Algül                8
# Name: count, dtype: int64

# %%
t.Director.value_counts(ascending=True).tail(10)
# Out:
# Category  Director
# TV Show   Cho Li, Chen Hung-yi, Weica Wang, Liu Bang-yao, Lin Guan-fu, Shen Chi, YC Tom Lee    1
#           Cosima Spender                                                                       1
#           Damien Chazelle, Houda Benyamina, Laïla Marrakchi, Alan Poul                         1
#           Ziad Doueiri                                                                         1
#           Rob Seidenglanz                                                                      2
#           Shin Won-ho                                                                          2
#           Stan Lathan                                                                          2
#           Ken Burns                                                                            2
#           Iginio Straffi                                                                       2
# ...

# %%
d.Director.value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# # Q15.  Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom" ?

# %%
t=d[d['Category']=='Movie']
r=t[t['Type']=='Comedies']
r[r['Country']=='United Kingdom']
# category==Movie and type == Comedies and Country == United Kingdom
# Out:
#      Show_Id Category                                              Title  \
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2225   s2226    Movie                                  For Love or Money
# 4210   s4211    Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4213   s4214    Movie           Monty Python: Live at The Hollywood Bowl
# 4781   s4782    Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 4792   s4793    Movie                                     PATRICK (2019)
# 6109   s6109    Movie                            The Bad Education Movie
# 6947   s6946    Movie                                  The Trip to Spain
#
#                            Director  \
# 1368                  James Dearden
# 1650                    Tom Edmunds
# 2225                    Mark Murphy
# 4210                      Eric Idle
# 4213  Terry Hughes, Ian MacNaughton
# ...

# %% [markdown]
# ###  check

# %%
d[(d['Category']=='Movie')&(d['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
d[(d['Category']=='Movie')&(d['Type']=='Comedies') | (d['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # Q16. In how many movies/shows, Tom Cruise was cast ?

# %%
d.Cast.unique()
# Out:
# array(['João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi',
#        'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato',
#        'Tedd Chan, Stella Chung, Henley Hii, Lawrence Koh, Tommy Kuan, Josh Lai, Mark Lee, Susan Leong, Benjamin Lim',
#        ...,
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy',
#        'Nasty C', 'Adriano Zumbo, Rachel Khoo'], dtype=object)

# %%
d[d['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
d[d['Cast'].str.contains('Tom Cruise',na=False)]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# ## Create new datasets

# %%
d.dropna()
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
d_new=d.dropna()

# %%
d_new[d_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# # Q17. What are the different Ratings defined by Netflix ?

# %%
d['Rating'].nunique()
# Out:
# 14

# %%
d.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q18. How many Movies got the 'TV-14' rating, in Canada ?

# %%
d[(d['Category']=="Movie") &(d['Rating']=='TV-14')& (d['Country']=='Canada')].shape
# Out:
# (11, 11)

# %% [markdown]
# # Q19. How many TV Show got the 'R' rating, after year 2018 ?

# %%
d[(d['Category']=="TV Show") &(d['Rating']=='R')& (d['Year']>2018)].shape
# Out:
# (1, 12)

# %%
d[(d['Category'].str.contains("TV Show")) &(d['Rating'].str.contains('R'))& (d['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %% [markdown]
# # Q20. What is the maximum duration of a Movie/Show on Netflix ?

# %%
d.sort_values(by='Duration',ascending=False)
# Out:
#      Show_Id Category                                      Title  \
# 2023   s2024    Movie  Errementari: The Blacksmith and the Devil
# 6716   s6715    Movie         The Nutcracker and the Four Realms
# 7023   s7022    Movie                                 The Worthy
# 2103   s2104    Movie                                   Familiye
# 2078   s2079    Movie                              Eyyvah Eyyvah
# ...      ...      ...                                        ...
# 6609   s6608  TV Show               The Lizzie Borden Chronicles
# 2027   s2028  TV Show         Especial 20 años Fútbol de Primera
# 2020   s2021  TV Show                                     Erased
# 740     s741  TV Show              Barbie Life in the Dreamhouse
# 4220   s4221  TV Show                    Monzón: A Knockout Blow
#
#                             Director  \
# 2023               Paul Urkijo Alijo
# 6716   Lasse Hallström, Joe Johnston
# 7023                  Ali F. Mostafa
# ...

# %%
d.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
d[['min','unit']]=d['Duration'].str.split(' ',expand=True)

# %%
d['min']=d['min'].astype(int)

# %%
d['min'].dtype
# Out:
# dtype('int32')

# %%
d['min'].max()
# Out:
# 312

# %%
d['min'].min()
# Out:
# 1

# %%
d['min'].mean()
# Out:
# 69.12954166131725

# %% [markdown]
# ## mind creativity

# %%
d.groupby(['unit'])['min'].max()
# Out:
# unit
# Season       1
# Seasons     16
# min        312
# Name: min, dtype: int32

# %% [markdown]
# ### 2nd

# %%
import numpy as np
d.groupby(['unit']).apply(lambda x:np.max(d['min']))
# Out:
# unit
# Season     312
# Seasons    312
# min        312
# dtype: int64

# %%
d_sea=d[d['unit']=='Season']
d_seas=d[d['unit']=='Seasons']
d_min=d[d['unit']=='min']

# %%
print('max season of show/web series is:',d_sea['min'].max())
print('max seasons of shows/web series is:',d_seas['min'].max())
print('max duration of min of movies is:',d_min['min'].max())
# Out:
# max season of show/web series is: 1
# max seasons of shows/web series is: 16
# max duration of min of movies is: 312

# %% [markdown]
# # Q21. Which individual country has the Highest No. of TV Shows ?

# %%
e=d[d['Category']=='TV Show']
e.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
e.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# # Q22. How can we sort the dataset by Year ?

# %%
d.sort_values(by='Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
d.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %% [markdown]
# # Q23. Find all the instances where : Category is 'Movie' and Type is 'Dramas'
# ##             or  Category is 'TV Show' & Type is 'Kids' TV' ?

# %%
s=d[d['Category']=='Movie']
s[s['Type']=='Dramas']
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
t=d[d['Category']=='TV Show']
t[t['Type']=="Kids' TV"]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %% [markdown]
# ## 2nd

# %%
d[(d['Category']=='Movie') & (d['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
d[(d['Category']=='TV Show') & (d['Type']=="Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %% [markdown]
# ## final

# %%
d[(d['Category']=='Movie') & (d['Type']=='Dramas') | (d['Category']=='TV Show') & (d['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
